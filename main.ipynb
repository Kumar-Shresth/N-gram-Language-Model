# %%
#10s
import pandas as pd

# Loading the train and test datasets
train_df = pd.read_csv("train.csv")
test_df = pd.read_csv("test.csv")

# Extracting 100 samples for validation
val_df = train_df.sample(n=100, random_state=13)

# Removing these 100 samples from the training set
train_df = train_df.drop(val_df.index)

# Saving updated train and validation sets
train_df.to_csv("train_cleaned.csv", index=False)
val_df.to_csv("validation.csv", index=False)

print("Training set size:", len(train_df))
print("Validation set size:", len(val_df))
# Out:
# Training set size: 13779
# Validation set size: 100

# %%
print("Test set size:", len(test_df))
# Out:
# Test set size: 100

# %% [markdown]
# Removing punctuations and non-ASCII characters

# %%
import re
#7s
def clean_text(text):
    text = re.sub(r'[^\x00-\x7F]+', ' ', text)  # Remove non-ASCII characters
    text = re.sub(r'[^\w\s]', '', text)  # Remove punctuation
    return text.lower()  # Convert to lowercase


#print("Sample cleaned text:", train_df["text"].iloc[0])

# %% [markdown]
# Removing Stop words

# %%
import nltk
#10s
from nltk.corpus import stopwords

#nltk.download('stopwords')
stop_words = set(stopwords.words('english'))

def remove_stopwords(text):
    return " ".join([word for word in text.split() if word not in stop_words])

# %% [markdown]
# Lemmatization

# %%
#150 sec
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet

#nltk.download('wordnet')

lemmatizer = WordNetLemmatizer()

def lemmatize_text(text):
    return " ".join([lemmatizer.lemmatize(word) for word in text.split()])


# print("Sample after lemmatization:", train_df["text"].iloc[0])

# %%
train_df["text"] = train_df["text"].str.lower().map(clean_text).map(remove_stopwords).map(lemmatize_text).str.strip()
val_df["text"] = val_df["text"].str.lower().map(clean_text).map(remove_stopwords).map(lemmatize_text).str.strip()
test_df["text"] = test_df["text"].str.lower().map(clean_text).map(remove_stopwords).map(lemmatize_text).str.strip()

# %% [markdown]
# Removing Extra Space

# %%
train_df["text"] = train_df["text"].str.replace(r'\s+', ' ', regex=True).str.strip()
val_df["text"] = val_df["text"].str.replace(r'\s+', ' ', regex=True).str.strip()
test_df["text"] = test_df["text"].str.replace(r'\s+', ' ', regex=True).str.strip()

# %% [markdown]
# Removing numbers

# %%
train_df["text"] = train_df["text"].str.replace(r'\d+', '', regex=True)
val_df["text"] = val_df["text"].str.replace(r'\d+', '', regex=True)
test_df["text"] = test_df["text"].str.replace(r'\d+', '', regex=True)

# %% [markdown]
# Tokenization

# %%
from nltk.tokenize import word_tokenize
#nltk.download('punkt')
#60s
def tokenize_text(text):
    return word_tokenize(text)

train_df["tokens"] = train_df["text"].apply(tokenize_text)
val_df["tokens"] = val_df["text"].apply(tokenize_text)

# print("Tokenized Sample:", train_df["tokens"].iloc[0])

# %%
test_df["tokens"] = test_df["text"].apply(tokenize_text)

# %%
train_df.to_csv("train_preprocessed.csv", index=False)
val_df.to_csv("validation_preprocessed.csv", index=False)
#12 s

# %% [markdown]
# # Generating N-grams

# %%
from collections import Counter
from itertools import islice

# Function to generate n-grams from a list of tokens
def generate_ngrams(tokens, n):
    return list(zip(*[tokens[i:] for i in range(n)]))#slicing will get us n lists(starting from 0,1,,,n-1, and then zip 
                                                    #takes one element from each list and make into tuple

# def generate_ngrams(tokens, n):
#     ngrams = []
#     for i in range(len(tokens) - n + 1):  # Ensure we don't go out of bounds
#         ngram = tuple(tokens[i:i+n])  # Create an n-gram tuple
#         ngrams.append(ngram)  # Add to the list
#     return ngrams
# Apply n-gram generation to each article in train set
train_df["unigrams"] = train_df["tokens"].apply(lambda x: generate_ngrams(x, 1))
train_df["bigrams"] = train_df["tokens"].apply(lambda x: generate_ngrams(x, 2))
train_df["trigrams"] = train_df["tokens"].apply(lambda x: generate_ngrams(x, 3))

# Display sample n-grams
print("Sample Unigrams:", train_df["unigrams"].iloc[0][:10])
print("Sample Bigrams:", train_df["bigrams"].iloc[0][:10])
print("Sample Trigrams:", train_df["trigrams"].iloc[0][:10])
# Out:
# Sample Unigrams: [('port',), ('st',), ('lucie',), ('city',), ('st',), ('lucie',), ('county',), ('florida',), ('united',), ('state',)]
# Sample Bigrams: [('port', 'st'), ('st', 'lucie'), ('lucie', 'city'), ('city', 'st'), ('st', 'lucie'), ('lucie', 'county'), ('county', 'florida'), ('florida', 'united'), ('united', 'state'), ('state', 'populous')]
# Sample Trigrams: [('port', 'st', 'lucie'), ('st', 'lucie', 'city'), ('lucie', 'city', 'st'), ('city', 'st', 'lucie'), ('st', 'lucie', 'county'), ('lucie', 'county', 'florida'), ('county', 'florida', 'united'), ('florida', 'united', 'state'), ('united', 'state', 'populous'), ('state', 'populous', 'municipality')]

# %%
test_df["bigrams"] = test_df["tokens"].apply(lambda x: generate_ngrams(x, 2))
test_df["unigrams"] = test_df["tokens"].apply(lambda x: generate_ngrams(x, 1))
test_df["trigrams"] = test_df["tokens"].apply(lambda x: generate_ngrams(x, 3))

# %%
#48 seconds
# Minimum threshold (1% of total training articles)
min_count = int(0.01 * len(train_df))

# Function to count how many articles contain each n-gram
def count_ngrams_across_articles(ngrams_list):
    ngram_article_counts = Counter()
    for ngrams in ngrams_list:
        unique_ngrams = set(ngrams)  # unique_ngrams is a set containing all 
        #unique n-grams from a single article
        ngram_article_counts.update(unique_ngrams)  # Increment count for each unique n-gram
    return ngram_article_counts

# Count n-grams in articles
unigram_counts = count_ngrams_across_articles(train_df["unigrams"])
bigram_counts = count_ngrams_across_articles(train_df["bigrams"])
trigram_counts = count_ngrams_across_articles(train_df["trigrams"])

# Filter n-grams that appear in at least 1% of training articles
filtered_unigrams = {ngram for ngram, count in unigram_counts.items() if count >= min_count}
#.items() gives (ngram, count) pairs. filtered_unigram is a set.
filtered_bigrams = {ngram for ngram, count in bigram_counts.items() if count >= min_count}
filtered_trigrams = {ngram for ngram, count in trigram_counts.items() if count >= min_count}

# Display results
print(f"Total Unigrams: {len(unigram_counts)}, Filtered: {len(filtered_unigrams)}")
print(f"Total Bigrams: {len(bigram_counts)}, Filtered: {len(filtered_bigrams)}")
print(f"Total Trigrams: {len(trigram_counts)}, Filtered: {len(filtered_trigrams)}")
# Out:
# Total Unigrams: 435746, Filtered: 8674
# Total Bigrams: 8007311, Filtered: 5099
# Total Trigrams: 15776177, Filtered: 1008

# %%
print("Filtered Unigrams Sample:", list(filtered_unigrams)[:10])
print("Total Filtered Unigrams:", len(filtered_unigrams))
# Out:
# Filtered Unigrams Sample: [('notion',), ('obtaining',), ('patent',), ('seated',), ('citrus',), ('hanna',), ('disestablished',), ('evan',), ('newton',), ('wildlife',)]
# Total Filtered Unigrams: 8674

# %% [markdown]
# # MLE with Laplace Smoothing

# %%
#40sec
# Function to compute MLE probability with Laplace smoothing
def compute_ngram_probabilities(ngram_counts, lower_ngram_counts, vocab_size, alpha=1):
    probabilities = {}
    for ngram, count in ngram_counts.items():
        prefix = ngram[:-1]  # (n-1)-gram prefix
        prefix_count = lower_ngram_counts.get(prefix, 0)  # Count of (n-1)-gram
        #get fetches a value for a given key, 0 is the default value
        probabilities[ngram] = (count + alpha) / (prefix_count + alpha * vocab_size)
    return probabilities

# Vocabulary size (total unique unigrams)
vocab_size = len(filtered_unigrams)

# Filter ngram_counts to include only those present in filtered_ngrams
filtered_unigram_counts = {ngram: count for ngram, count in unigram_counts.items() if ngram in filtered_unigrams}
filtered_bigram_counts = {ngram: count for ngram, count in bigram_counts.items() if ngram in filtered_bigrams}
filtered_trigram_counts = {ngram: count for ngram, count in trigram_counts.items() if ngram in filtered_trigrams}

# Compute probabilities using only the filtered n-grams
unigram_probs = compute_ngram_probabilities(filtered_unigram_counts, {}, vocab_size)
bigram_probs = compute_ngram_probabilities(filtered_bigram_counts, filtered_unigram_counts, vocab_size)
trigram_probs = compute_ngram_probabilities(filtered_trigram_counts, filtered_bigram_counts, vocab_size)

# Display some probabilities
print("Sample Unigram Probability:", list(unigram_probs.items())[:5])
print("Sample Bigram Probability:", list(bigram_probs.items())[:5])
print("Sample Trigram Probability:", list(trigram_probs.items())[:5])
# Out:
# Sample Unigram Probability: [(('david',), 0.4760202905234033), (('tropical',), 0.03389439704865114), (('infrastructure',), 0.12324187226193221), (('maintaining',), 0.04184920451925294), (('shopping',), 0.10721697025593728)]
# Sample Bigram Probability: [(('en', 'route'), 0.04881641241451867), (('also', 'located'), 0.016719976737423668), (('asian', 'pacific'), 0.11167601683029453), (('including', 'age'), 0.1034668905950096), (('population', 'census'), 0.10491676345334881)]
# Sample Trigram Probability: [(('living', 'together', 'female'), 0.18173302107728337), (('size', 'average', 'family'), 0.18413384716608705), (('age', 'year', 'every'), 0.16950092421441776), (('average', 'household', 'size'), 0.18792071802543006), (('census', 'bureau', 'city'), 0.10436504195342698)]

# %%
import numpy as np

def compute_perplexity(tokens, ngram_probs, n):
    N = len(tokens)  # Length of the test article
    log_prob_sum = 0  
    unseen_count = 0  # Count of unseen n-grams

    for i in range(len(tokens) - n + 1):  # Sliding window for n-grams
        ngram = tuple(tokens[i:i+n])
        prob = ngram_probs.get(ngram, 0)  # Get probability, 0 if unseen
        
        if prob == 0:
            unseen_count += 1  # Track how many times we hit an unseen n-gram
        else:
            log_prob_sum += np.log(prob)  # Sum of log probabilities

    if unseen_count == N:  # If all n-grams are unseen, return high perplexity
        return float('inf')

    avg_log_prob = log_prob_sum / N  # Average log probability
    return np.exp(-avg_log_prob)  # Perplexity formula

# %%
unigram_perplexities = [compute_perplexity(tokens, unigram_probs, n=1) for tokens in test_df["tokens"]]
bigram_perplexities = [compute_perplexity(tokens, bigram_probs, n=2) for tokens in test_df["tokens"]]
trigram_perplexities = [compute_perplexity(tokens, trigram_probs, n=3) for tokens in test_df["tokens"]]

# Compute overall average perplexity
avg_unigram_perplexity = np.mean(unigram_perplexities)
avg_bigram_perplexity = np.mean(bigram_perplexities)
avg_trigram_perplexity = np.mean(trigram_perplexities)

print(f"Unigram Model Perplexity: {avg_unigram_perplexity}")
print(f"Bigram Model Perplexity: {avg_bigram_perplexity}")
print(f"Trigram Model Perplexity: {avg_trigram_perplexity}")
# Out:
# Unigram Model Perplexity: 3.177360199688495
# Bigram Model Perplexity: 1.8214216136747892
# Trigram Model Perplexity: 1.200521810584277

# %%
train_bigrams = set(bigram for bigrams in train_df["bigrams"] for bigram in bigrams)

# %%
test_bigrams = set(bigram for bigrams in test_df["bigrams"] for bigram in bigrams)

# %%
unseen_bigrams = test_bigrams - train_bigrams
print(f"Number of unseen bigrams: {len(unseen_bigrams)}")
# Out:
# Number of unseen bigrams: 47039

# %%
train_unigrams = set(unigram for unigrams in train_df["unigrams"] for unigram in unigrams)

# %%
test_unigrams = set(unigram for unigrams in test_df["unigrams"] for unigram in unigrams)

# %%
unseen_unigrams = test_unigrams - train_unigrams
print(f"Number of unseen unigrams: {len(unseen_unigrams)}")
# Out:
# Number of unseen unigrams: 1786

# %%
train_trigrams = set(trigram for trigrams in train_df["trigrams"] for trigram in trigrams)

# %%
test_trigrams = set(trigram for trigrams in test_df["trigrams"] for trigram in trigrams)

# %%
unseen_trigrams = test_trigrams - train_trigrams
print(f"Number of unseen trigrams: {len(unseen_trigrams)}")
# Out:
# Number of unseen trigrams: 110664

# %%
unseen_bigram_count = sum(1 for prob in bigram_probs.values() if prob == 0)
unseen_trigram_count = sum(1 for prob in trigram_probs.values() if prob == 0)

print("Zero probability bigrams:", unseen_bigram_count)
print("Zero probability trigrams:", unseen_trigram_count)
# Out:
# Zero probability bigrams: 0
# Zero probability trigrams: 0

# %%
bigram_probs_list = [bigram_probs.get(bigram, 0) for bigrams in test_df["bigrams"] for bigram in bigrams]
trigram_probs_list = [trigram_probs.get(trigram, 0) for trigrams in test_df["trigrams"] for trigram in trigrams]

print("Average Bigram Probability:", np.mean(bigram_probs_list))
print("Average Trigram Probability:", np.mean(trigram_probs_list))
# Out:
# Average Bigram Probability: 0.009795097429667362
# Average Trigram Probability: 0.0030489062637462116

# %%
validation_tokens = val_df["tokens"].tolist()

# %%
print("Validation tokens length:", len(validation_tokens))
# Out:
# Validation tokens length: 100

# %%
validation_tokens = [token for sentence in validation_tokens for token in sentence]

# %%
# Perplexity function for interpolation
def perplexity_interpolation(lambdas, validation_tokens, unigram_probs, bigram_probs, trigram_probs):
    lambda1, lambda2, lambda3 = lambdas  # λ1 for trigrams, λ2 for bigrams, λ3 for unigrams
    N = len(validation_tokens)
    log_prob_sum = 0

    for i in range(len(validation_tokens) - 2):  # Iterate through trigrams
        trigram = tuple(validation_tokens[i:i+3])
        bigram = tuple(trigram[1:])
        unigram = (trigram[-1],)  # Ensure it's a tuple

        # Get probabilities, defaulting to a small value to avoid log(0)
        p_trigram = trigram_probs.get(trigram, 1e-10)
        p_bigram = bigram_probs.get(bigram, 1e-10)
        p_unigram = unigram_probs.get(unigram, 1e-10)

        # Compute interpolated probability
        interpolated_prob = lambda1 * p_trigram + lambda2 * p_bigram + lambda3 * p_unigram
        interpolated_prob = max(interpolated_prob, 1e-10)  # Ensure nonzero probability
        
        log_prob_sum += np.log(interpolated_prob)

    avg_log_prob = log_prob_sum / N
    return np.exp(-avg_log_prob)  # Perplexity

# %%
print(validation_tokens[:20])
# Out:
# ['weymouth', 'city', 'norfolk', 'county', 'massachusetts', 'one', 'municipality', 'state', 'city', 'form', 'government', 'retaining', 'town', 'official', 'name', 'named', 'weymouth', 'dorset', 'coastal', 'town']

# %%
for i in range(len(validation_tokens) - 2):  # Iterate through trigrams
    trigram = tuple(validation_tokens[i:i+3])
    bigram = tuple(trigram[1:])
    unigram = (trigram[-1],)  # Ensure it's a tuple

    print(f"Trigram: {trigram}, Bigram: {bigram}, Unigram: {unigram}")

    p_trigram = trigram_probs.get(trigram, 1e-10)
    p_bigram = bigram_probs.get(bigram, 1e-10)
    p_unigram = unigram_probs.get(unigram, 1e-10)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Trigram: ('list', 'influential', 'sport'), Bigram: ('influential', 'sport'), Unigram: ('sport',)
# Trigram: ('influential', 'sport', 'figure'), Bigram: ('sport', 'figure'), Unigram: ('figure',)
# Trigram: ('sport', 'figure', 'th'), Bigram: ('figure', 'th'), Unigram: ('th',)
# Trigram: ('figure', 'th', 'century'), Bigram: ('th', 'century'), Unigram: ('century',)
# Trigram: ('th', 'century', 'july'), Bigram: ('century', 'july'), Unigram: ('july',)
# Trigram: ('century', 'july', 'walter'), Bigram: ('july', 'walter'), Unigram: ('walter',)
# Trigram: ('july', 'walter', 'omalley'), Bigram: ('walter', 'omalley'), Unigram: ('omalley',)
# Trigram: ('walter', 'omalley', 'inducted'), Bigram: ('omalley', 'inducted'), Unigram: ('inducted',)
# Trigram: ('omalley', 'inducted', 'irish'), Bigram: ('inducted', 'irish'), Unigram: ('irish',)
# Trigram: ('inducted', 'irish', 'american'), Bigram: ('irish', 'american'), Unigram: ('american',)
# Trigram: ('irish', 'american', 'baseball'), Bigram: ('american', 'baseball'), Unigram: ('baseball',)
# Trigram: ('american', 'baseball', 'hall'), Bigram: ('baseball', 'hall'), Unigram: ('hall',)
# Trigram: ('baseball', 'hall', 'fame'), Bigram: ('hall', 'fame'), Unigram: ('fame',)
# Trigram: ('hall', 'fame', 'along'), Bigram: ('fame', 'along'), Unigram: ('along',)
# Trigram: ('fame', 'along', 'two'), Bigram: ('along', 'two'), Unigram: ('two',)
# Trigram: ('along', 'two', 'dodger'), Bigram: ('two', 'dodger'), Unigram: ('dodger',)
# Trigram: ('two', 'dodger', 'icon'), Bigram: ('dodger', 'icon'), Unigram: ('icon',)
# Trigram: ('dodger', 'icon', 'slugger'), Bigram: ('icon', 'slugger'), Unigram: ('slugger',)
# Trigram: ('icon', 'slugger', 'steve'), Bigram: ('slugger', 'steve'), Unigram: ('steve',)
# Trigram: ('slugger', 'steve', 'garvey'), Bigram: ('steve', 'garvey'), Unigram: ('garvey',)
# Trigram: ('steve', 'garvey', 'announcer'), Bigram: ('garvey', 'announcer'), Unigram: ('announcer',)
# Trigram: ('garvey', 'announcer', 'vin'), Bigram: ('announcer', 'vin'), Unigram: ('vin',)
# Trigram: ('announcer', 'vin', 'scully'), Bigram: ('vin', 'scully'), Unigram: ('scully',)
# Trigram: ('vin', 'scully', 'year'), Bigram: ('scully', 'year'), Unigram: ('year',)
# Trigram: ('scully', 'year', 'learned'), Bigram: ('year', 'learned'), Unigram: ('learned',)
# Trigram: ('year', 'learned', 'decadelong'), Bigram: ('learned', 'decadelong'), Unigram: ('decadelong',)
# Trigram: ('learned', 'decadelong', 'quest'), Bigram: ('decadelong', 'quest'), Unigram: ('quest',)
# Trigram: ('decadelong', 'quest', 'build'), Bigram: ('quest', 'build'), Unigram: ('build',)
# Trigram: ('quest', 'build', 'new'), Bigram: ('build', 'new'), Unigram: ('new',)
# Trigram: ('build', 'new', 'stadium'), Bigram: ('new', 'stadium'), Unigram: ('stadium',)
# Trigram: ('new', 'stadium', 'brooklyn'), Bigram: ('stadium', 'brooklyn'), Unigram: ('brooklyn',)
# Trigram: ('stadium', 'brooklyn', 'effort'), Bigram: ('brooklyn', 'effort'), Unigram: ('effort',)
# Trigram: ('brooklyn', 'effort', 'thwarted'), Bigram: ('effort', 'thwarted'), Unigram: ('thwarted',)
# Trigram: ('effort', 'thwarted', 'city'), Bigram: ('thwarted', 'city'), Unigram: ('city',)
# Trigram: ('thwarted', 'city', 'official'), Bigram: ('city', 'official'), Unigram: ('official',)
# Trigram: ('city', 'official', 'perhaps'), Bigram: ('official', 'perhaps'), Unigram: ('perhaps',)
# Trigram: ('official', 'perhaps', 'induction'), Bigram: ('perhaps', 'induction'), Unigram: ('induction',)
# Trigram: ('perhaps', 'induction', 'inspire'), Bigram: ('induction', 'inspire'), Unigram: ('inspire',)
# Trigram: ('induction', 'inspire', 'fan'), Bigram: ('inspire', 'fan'), Unigram: ('fan',)
# Trigram: ('inspire', 'fan', 'started'), Bigram: ('fan', 'started'), Unigram: ('started',)
# Trigram: ('fan', 'started', 'new'), Bigram: ('started', 'new'), Unigram: ('new',)
# Trigram: ('started', 'new', 'life'), Bigram: ('new', 'life'), Unigram: ('life',)
# Trigram: ('new', 'life', 'outside'), Bigram: ('life', 'outside'), Unigram: ('outside',)
# Trigram: ('life', 'outside', 'borough'), Bigram: ('outside', 'borough'), Unigram: ('borough',)
# Trigram: ('outside', 'borough', 'reconsider'), Bigram: ('borough', 'reconsider'), Unigram: ('reconsider',)
# Trigram: ('borough', 'reconsider', 'thought'), Bigram: ('reconsider', 'thought'), Unigram: ('thought',)
# Trigram: ('reconsider', 'thought', 'walter'), Bigram: ('thought', 'walter'), Unigram: ('walter',)
# Trigram: ('thought', 'walter', 'omalley'), Bigram: ('walter', 'omalley'), Unigram: ('omalley',)
# Trigram: ('walter', 'omalley', 'said'), Bigram: ('omalley', 'said'), Unigram: ('said',)
# Trigram: ('omalley', 'said', 'john'), Bigram: ('said', 'john'), Unigram: ('john',)
# Trigram: ('said', 'john', 'mooney'), Bigram: ('john', 'mooney'), Unigram: ('mooney',)
# Trigram: ('john', 'mooney', 'curator'), Bigram: ('mooney', 'curator'), Unigram: ('curator',)
# Trigram: ('mooney', 'curator', 'irish'), Bigram: ('curator', 'irish'), Unigram: ('irish',)
# Trigram: ('curator', 'irish', 'american'), Bigram: ('irish', 'american'), Unigram: ('american',)
# Trigram: ('irish', 'american', 'baseball'), Bigram: ('american', 'baseball'), Unigram: ('baseball',)
# Trigram: ('american', 'baseball', 'hall'), Bigram: ('baseball', 'hall'), Unigram: ('hall',)
# Trigram: ('baseball', 'hall', 'fame'), Bigram: ('hall', 'fame'), Unigram: ('fame',)
# Trigram: ('hall', 'fame', 'privately'), Bigram: ('fame', 'privately'), Unigram: ('privately',)
# Trigram: ('fame', 'privately', 'built'), Bigram: ('privately', 'built'), Unigram: ('built',)
# Trigram: ('privately', 'built', 'one'), Bigram: ('built', 'one'), Unigram: ('one',)
# Trigram: ('built', 'one', 'baseball'), Bigram: ('one', 'baseball'), Unigram: ('baseball',)
# Trigram: ('one', 'baseball', 'beautiful'), Bigram: ('baseball', 'beautiful'), Unigram: ('beautiful',)
# Trigram: ('baseball', 'beautiful', 'ballpark'), Bigram: ('beautiful', 'ballpark'), Unigram: ('ballpark',)
# Trigram: ('beautiful', 'ballpark', 'dodger'), Bigram: ('ballpark', 'dodger'), Unigram: ('dodger',)
# Trigram: ('ballpark', 'dodger', 'stadium'), Bigram: ('dodger', 'stadium'), Unigram: ('stadium',)
# Trigram: ('dodger', 'stadium', 'set'), Bigram: ('stadium', 'set'), Unigram: ('set',)
# Trigram: ('stadium', 'set', 'attendance'), Bigram: ('set', 'attendance'), Unigram: ('attendance',)
# Trigram: ('set', 'attendance', 'record'), Bigram: ('attendance', 'record'), Unigram: ('record',)
# Trigram: ('attendance', 'record', 'annually'), Bigram: ('record', 'annually'), Unigram: ('annually',)
# Trigram: ('record', 'annually', 'new'), Bigram: ('annually', 'new'), Unigram: ('new',)
# Trigram: ('annually', 'new', 'york'), Bigram: ('new', 'york'), Unigram: ('york',)
# Trigram: ('new', 'york', 'home'), Bigram: ('york', 'home'), Unigram: ('home',)
# Trigram: ('york', 'home', 'irish'), Bigram: ('home', 'irish'), Unigram: ('irish',)
# Trigram: ('home', 'irish', 'american'), Bigram: ('irish', 'american'), Unigram: ('american',)
# Trigram: ('irish', 'american', 'baseball'), Bigram: ('american', 'baseball'), Unigram: ('baseball',)
# Trigram: ('american', 'baseball', 'hall'), Bigram: ('baseball', 'hall'), Unigram: ('hall',)
# Trigram: ('baseball', 'hall', 'fame'), Bigram: ('hall', 'fame'), Unigram: ('fame',)
# Trigram: ('hall', 'fame', 'seek'), Bigram: ('fame', 'seek'), Unigram: ('seek',)
# Trigram: ('fame', 'seek', 'honor'), Bigram: ('seek', 'honor'), Unigram: ('honor',)
# Trigram: ('seek', 'honor', 'inductee'), Bigram: ('honor', 'inductee'), Unigram: ('inductee',)
# Trigram: ('honor', 'inductee', 'whose'), Bigram: ('inductee', 'whose'), Unigram: ('whose',)
# Trigram: ('inductee', 'whose', 'impact'), Bigram: ('whose', 'impact'), Unigram: ('impact',)
# Trigram: ('whose', 'impact', 'national'), Bigram: ('impact', 'national'), Unigram: ('national',)
# Trigram: ('impact', 'national', 'omalleys'), Bigram: ('national', 'omalleys'), Unigram: ('omalleys',)
# Trigram: ('national', 'omalleys', 'detractor'), Bigram: ('omalleys', 'detractor'), Unigram: ('detractor',)
# Trigram: ('omalleys', 'detractor', 'say'), Bigram: ('detractor', 'say'), Unigram: ('say',)
# Trigram: ('detractor', 'say', 'visionary'), Bigram: ('say', 'visionary'), Unigram: ('visionary',)
# Trigram: ('say', 'visionary', 'taking'), Bigram: ('visionary', 'taking'), Unigram: ('taking',)
# Trigram: ('visionary', 'taking', 'baseball'), Bigram: ('taking', 'baseball'), Unigram: ('baseball',)
# Trigram: ('taking', 'baseball', 'west'), Bigram: ('baseball', 'west'), Unigram: ('west',)
# Trigram: ('baseball', 'west', 'say'), Bigram: ('west', 'say'), Unigram: ('say',)
# Trigram: ('west', 'say', 'game'), Bigram: ('say', 'game'), Unigram: ('game',)
# Trigram: ('say', 'game', 'naturally'), Bigram: ('game', 'naturally'), Unigram: ('naturally',)
# Trigram: ('game', 'naturally', 'heading'), Bigram: ('naturally', 'heading'), Unigram: ('heading',)
# Trigram: ('naturally', 'heading', 'toward'), Bigram: ('heading', 'toward'), Unigram: ('toward',)
# Trigram: ('heading', 'toward', 'geographical'), Bigram: ('toward', 'geographical'), Unigram: ('geographical',)
# Trigram: ('toward', 'geographical', 'expansion'), Bigram: ('geographical', 'expansion'), Unigram: ('expansion',)
# Trigram: ('geographical', 'expansion', 'omalley'), Bigram: ('expansion', 'omalley'), Unigram: ('omalley',)
# Trigram: ('expansion', 'omalley', 'opportunist'), Bigram: ('omalley', 'opportunist'), Unigram: ('opportunist',)
# Trigram: ('omalley', 'opportunist', 'rather'), Bigram: ('opportunist', 'rather'), Unigram: ('rather',)
# Trigram: ('opportunist', 'rather', 'truly'), Bigram: ('rather', 'truly'), Unigram: ('truly',)
# Trigram: ('rather', 'truly', 'leader'), Bigram: ('truly', 'leader'), Unigram: ('leader',)
# Trigram: ('truly', 'leader', 'detractor'), Bigram: ('leader', 'detractor'), Unigram: ('detractor',)
# Trigram: ('leader', 'detractor', 'say'), Bigram: ('detractor', 'say'), Unigram: ('say',)
# Trigram: ('detractor', 'say', 'leadership'), Bigram: ('say', 'leadership'), Unigram: ('leadership',)
# Trigram: ('say', 'leadership', 'manifestation'), Bigram: ('leadership', 'manifestation'), Unigram: ('manifestation',)
# Trigram: ('leadership', 'manifestation', 'making'), Bigram: ('manifestation', 'making'), Unigram: ('making',)
# Trigram: ('manifestation', 'making', 'money'), Bigram: ('making', 'money'), Unigram: ('money',)
# Trigram: ('making', 'money', 'popular'), Bigram: ('money', 'popular'), Unigram: ('popular',)
# Trigram: ('money', 'popular', 'culture'), Bigram: ('popular', 'culture'), Unigram: ('culture',)
# Trigram: ('popular', 'culture', 'omalley'), Bigram: ('culture', 'omalley'), Unigram: ('omalley',)
# Trigram: ('culture', 'omalley', 'mentioned'), Bigram: ('omalley', 'mentioned'), Unigram: ('mentioned',)
# Trigram: ('omalley', 'mentioned', 'several'), Bigram: ('mentioned', 'several'), Unigram: ('several',)
# Trigram: ('mentioned', 'several', 'time'), Bigram: ('several', 'time'), Unigram: ('time',)
# Trigram: ('several', 'time', 'danny'), Bigram: ('time', 'danny'), Unigram: ('danny',)
# Trigram: ('time', 'danny', 'kayes'), Bigram: ('danny', 'kayes'), Unigram: ('kayes',)
# Trigram: ('danny', 'kayes', 'song'), Bigram: ('kayes', 'song'), Unigram: ('song',)
# Trigram: ('kayes', 'song', 'tribute'), Bigram: ('song', 'tribute'), Unigram: ('tribute',)
# Trigram: ('song', 'tribute', 'dodger'), Bigram: ('tribute', 'dodger'), Unigram: ('dodger',)
# Trigram: ('tribute', 'dodger', 'song'), Bigram: ('dodger', 'song'), Unigram: ('song',)
# Trigram: ('dodger', 'song', 'oh'), Bigram: ('song', 'oh'), Unigram: ('oh',)
# Trigram: ('song', 'oh', 'really'), Bigram: ('oh', 'really'), Unigram: ('really',)
# Trigram: ('oh', 'really', 'omalley'), Bigram: ('really', 'omalley'), Unigram: ('omalley',)
# Trigram: ('really', 'omalley', 'spin'), Bigram: ('omalley', 'spin'), Unigram: ('spin',)
# Trigram: ('omalley', 'spin', 'tale'), Bigram: ('spin', 'tale'), Unigram: ('tale',)
# Trigram: ('spin', 'tale', 'fantasy'), Bigram: ('tale', 'fantasy'), Unigram: ('fantasy',)
# Trigram: ('tale', 'fantasy', 'game'), Bigram: ('fantasy', 'game'), Unigram: ('game',)
# Trigram: ('fantasy', 'game', 'dodger'), Bigram: ('game', 'dodger'), Unigram: ('dodger',)
# Trigram: ('game', 'dodger', 'giant'), Bigram: ('dodger', 'giant'), Unigram: ('giant',)
# Trigram: ('dodger', 'giant', 'one'), Bigram: ('giant', 'one'), Unigram: ('one',)
# Trigram: ('giant', 'one', 'point'), Bigram: ('one', 'point'), Unigram: ('point',)
# Trigram: ('one', 'point', 'umpire'), Bigram: ('point', 'umpire'), Unigram: ('umpire',)
# Trigram: ('point', 'umpire', 'call'), Bigram: ('umpire', 'call'), Unigram: ('call',)
# Trigram: ('umpire', 'call', 'go'), Bigram: ('call', 'go'), Unigram: ('go',)
# Trigram: ('call', 'go', 'home'), Bigram: ('go', 'home'), Unigram: ('home',)
# Trigram: ('go', 'home', 'team'), Bigram: ('home', 'team'), Unigram: ('team',)
# Trigram: ('home', 'team', 'dugout'), Bigram: ('team', 'dugout'), Unigram: ('dugout',)
# Trigram: ('team', 'dugout', 'alston'), Bigram: ('dugout', 'alston'), Unigram: ('alston',)
# Trigram: ('dugout', 'alston', 'glower'), Bigram: ('alston', 'glower'), Unigram: ('glower',)
# Trigram: ('alston', 'glower', 'booth'), Bigram: ('glower', 'booth'), Unigram: ('booth',)
# Trigram: ('glower', 'booth', 'vin'), Bigram: ('booth', 'vin'), Unigram: ('vin',)
# Trigram: ('booth', 'vin', 'scully'), Bigram: ('vin', 'scully'), Unigram: ('scully',)
# Trigram: ('vin', 'scully', 'frown'), Bigram: ('scully', 'frown'), Unigram: ('frown',)
# Trigram: ('scully', 'frown', 'stand'), Bigram: ('frown', 'stand'), Unigram: ('stand',)
# Trigram: ('frown', 'stand', 'omalley'), Bigram: ('stand', 'omalley'), Unigram: ('omalley',)
# Trigram: ('stand', 'omalley', 'grin'), Bigram: ('omalley', 'grin'), Unigram: ('grin',)
# Trigram: ('omalley', 'grin', 'attendance'), Bigram: ('grin', 'attendance'), Unigram: ('attendance',)
# Trigram: ('grin', 'attendance', 'omalley'), Bigram: ('attendance', 'omalley'), Unigram: ('omalley',)
# Trigram: ('attendance', 'omalley', 'charge'), Bigram: ('omalley', 'charge'), Unigram: ('charge',)
# Trigram: ('omalley', 'charge', 'omalley'), Bigram: ('charge', 'omalley'), Unigram: ('omalley',)
# Trigram: ('charge', 'omalley', 'featured'), Bigram: ('omalley', 'featured'), Unigram: ('featured',)
# Trigram: ('omalley', 'featured', 'prominently'), Bigram: ('featured', 'prominently'), Unigram: ('prominently',)
# Trigram: ('featured', 'prominently', 'hbo'), Bigram: ('prominently', 'hbo'), Unigram: ('hbo',)
# Trigram: ('prominently', 'hbo', 'documentary'), Bigram: ('hbo', 'documentary'), Unigram: ('documentary',)
# Trigram: ('hbo', 'documentary', 'film'), Bigram: ('documentary', 'film'), Unigram: ('film',)
# Trigram: ('documentary', 'film', 'brooklyn'), Bigram: ('film', 'brooklyn'), Unigram: ('brooklyn',)
# Trigram: ('film', 'brooklyn', 'dodger'), Bigram: ('brooklyn', 'dodger'), Unigram: ('dodger',)
# Trigram: ('brooklyn', 'dodger', 'ghost'), Bigram: ('dodger', 'ghost'), Unigram: ('ghost',)
# Trigram: ('dodger', 'ghost', 'flatbush'), Bigram: ('ghost', 'flatbush'), Unigram: ('flatbush',)
# Trigram: ('ghost', 'flatbush', 'chronicled'), Bigram: ('flatbush', 'chronicled'), Unigram: ('chronicled',)
# Trigram: ('flatbush', 'chronicled', 'executive'), Bigram: ('chronicled', 'executive'), Unigram: ('executive',)
# Trigram: ('chronicled', 'executive', 'management'), Bigram: ('executive', 'management'), Unigram: ('management',)
# Trigram: ('executive', 'management', 'brooklynlos'), Bigram: ('management', 'brooklynlos'), Unigram: ('brooklynlos',)
# Trigram: ('management', 'brooklynlos', 'angeles'), Bigram: ('brooklynlos', 'angeles'), Unigram: ('angeles',)
# Trigram: ('brooklynlos', 'angeles', 'dodger'), Bigram: ('angeles', 'dodger'), Unigram: ('dodger',)
# Trigram: ('angeles', 'dodger', 'documentary'), Bigram: ('dodger', 'documentary'), Unigram: ('documentary',)
# Trigram: ('dodger', 'documentary', 'focus'), Bigram: ('documentary', 'focus'), Unigram: ('focus',)
# Trigram: ('documentary', 'focus', 'post'), Bigram: ('focus', 'post'), Unigram: ('post',)
# Trigram: ('focus', 'post', 'world'), Bigram: ('post', 'world'), Unigram: ('world',)
# Trigram: ('post', 'world', 'war'), Bigram: ('world', 'war'), Unigram: ('war',)
# Trigram: ('world', 'war', 'ii'), Bigram: ('war', 'ii'), Unigram: ('ii',)
# Trigram: ('war', 'ii', 'glory'), Bigram: ('ii', 'glory'), Unigram: ('glory',)
# Trigram: ('ii', 'glory', 'year'), Bigram: ('glory', 'year'), Unigram: ('year',)
# Trigram: ('glory', 'year', 'franchise'), Bigram: ('year', 'franchise'), Unigram: ('franchise',)
# Trigram: ('year', 'franchise', 'present'), Bigram: ('franchise', 'present'), Unigram: ('present',)
# Trigram: ('franchise', 'present', 'compelling'), Bigram: ('present', 'compelling'), Unigram: ('compelling',)
# Trigram: ('present', 'compelling', 'case'), Bigram: ('compelling', 'case'), Unigram: ('case',)
# Trigram: ('compelling', 'case', 'omalley'), Bigram: ('case', 'omalley'), Unigram: ('omalley',)
# Trigram: ('case', 'omalley', 'truly'), Bigram: ('omalley', 'truly'), Unigram: ('truly',)
# Trigram: ('omalley', 'truly', 'wanted'), Bigram: ('truly', 'wanted'), Unigram: ('wanted',)
# Trigram: ('truly', 'wanted', 'keep'), Bigram: ('wanted', 'keep'), Unigram: ('keep',)
# Trigram: ('wanted', 'keep', 'dodger'), Bigram: ('keep', 'dodger'), Unigram: ('dodger',)
# Trigram: ('keep', 'dodger', 'brooklyn'), Bigram: ('dodger', 'brooklyn'), Unigram: ('brooklyn',)
# Trigram: ('dodger', 'brooklyn', 'stadium'), Bigram: ('brooklyn', 'stadium'), Unigram: ('stadium',)
# Trigram: ('brooklyn', 'stadium', 'near'), Bigram: ('stadium', 'near'), Unigram: ('near',)
# Trigram: ('stadium', 'near', 'railroad'), Bigram: ('near', 'railroad'), Unigram: ('railroad',)
# Trigram: ('near', 'railroad', 'station'), Bigram: ('railroad', 'station'), Unigram: ('station',)
# Trigram: ('railroad', 'station', 'unable'), Bigram: ('station', 'unable'), Unigram: ('unable',)
# Trigram: ('station', 'unable', 'get'), Bigram: ('unable', 'get'), Unigram: ('get',)
# Trigram: ('unable', 'get', 'proper'), Bigram: ('get', 'proper'), Unigram: ('proper',)
# Trigram: ('get', 'proper', 'support'), Bigram: ('proper', 'support'), Unigram: ('support',)
# Trigram: ('proper', 'support', 'moses'), Bigram: ('support', 'moses'), Unigram: ('moses',)
# Trigram: ('support', 'moses', 'timeline'), Bigram: ('moses', 'timeline'), Unigram: ('timeline',)
# Trigram: ('moses', 'timeline', 'birth'), Bigram: ('timeline', 'birth'), Unigram: ('birth',)
# Trigram: ('timeline', 'birth', 'new'), Bigram: ('birth', 'new'), Unigram: ('new',)
# Trigram: ('birth', 'new', 'york'), Bigram: ('new', 'york'), Unigram: ('york',)
# Trigram: ('new', 'york', 'city'), Bigram: ('york', 'city'), Unigram: ('city',)
# Trigram: ('york', 'city', 'october'), Bigram: ('city', 'october'), Unigram: ('october',)
# Trigram: ('city', 'october', 'graduation'), Bigram: ('october', 'graduation'), Unigram: ('graduation',)
# Trigram: ('october', 'graduation', 'university'), Bigram: ('graduation', 'university'), Unigram: ('university',)
# Trigram: ('graduation', 'university', 'pennsylvania'), Bigram: ('university', 'pennsylvania'), Unigram: ('pennsylvania',)
# Trigram: ('university', 'pennsylvania', 'stock'), Bigram: ('pennsylvania', 'stock'), Unigram: ('stock',)
# Trigram: ('pennsylvania', 'stock', 'market'), Bigram: ('stock', 'market'), Unigram: ('market',)
# Trigram: ('stock', 'market', 'crash'), Bigram: ('market', 'crash'), Unigram: ('crash',)
# Trigram: ('market', 'crash', 'law'), Bigram: ('crash', 'law'), Unigram: ('law',)
# Trigram: ('crash', 'law', 'degree'), Bigram: ('law', 'degree'), Unigram: ('degree',)
# Trigram: ('law', 'degree', 'fordham'), Bigram: ('degree', 'fordham'), Unigram: ('fordham',)
# Trigram: ('degree', 'fordham', 'university'), Bigram: ('fordham', 'university'), Unigram: ('university',)
# Trigram: ('fordham', 'university', 'marriage'), Bigram: ('university', 'marriage'), Unigram: ('marriage',)
# Trigram: ('university', 'marriage', 'katherine'), Bigram: ('marriage', 'katherine'), Unigram: ('katherine',)
# Trigram: ('marriage', 'katherine', 'elizabeth'), Bigram: ('katherine', 'elizabeth'), Unigram: ('elizabeth',)
# Trigram: ('katherine', 'elizabeth', 'hanson'), Bigram: ('elizabeth', 'hanson'), Unigram: ('hanson',)
# Trigram: ('elizabeth', 'hanson', 'aka'), Bigram: ('hanson', 'aka'), Unigram: ('aka',)
# Trigram: ('hanson', 'aka', 'kay'), Bigram: ('aka', 'kay'), Unigram: ('kay',)
# Trigram: ('aka', 'kay', 'hanson'), Bigram: ('kay', 'hanson'), Unigram: ('hanson',)
# Trigram: ('kay', 'hanson', 'september'), Bigram: ('hanson', 'september'), Unigram: ('september',)
# Trigram: ('hanson', 'september', 'birth'), Bigram: ('september', 'birth'), Unigram: ('birth',)
# Trigram: ('september', 'birth', 'therese'), Bigram: ('birth', 'therese'), Unigram: ('therese',)
# Trigram: ('birth', 'therese', 'omalley'), Bigram: ('therese', 'omalley'), Unigram: ('omalley',)
# Trigram: ('therese', 'omalley', 'daughter'), Bigram: ('omalley', 'daughter'), Unigram: ('daughter',)
# Trigram: ('omalley', 'daughter', 'may'), Bigram: ('daughter', 'may'), Unigram: ('may',)
# Trigram: ('daughter', 'may', 'birth'), Bigram: ('may', 'birth'), Unigram: ('birth',)
# Trigram: ('may', 'birth', 'peter'), Bigram: ('birth', 'peter'), Unigram: ('peter',)
# Trigram: ('birth', 'peter', 'omalley'), Bigram: ('peter', 'omalley'), Unigram: ('omalley',)
# Trigram: ('peter', 'omalley', 'son'), Bigram: ('omalley', 'son'), Unigram: ('son',)
# Trigram: ('omalley', 'son', 'december'), Bigram: ('son', 'december'), Unigram: ('december',)
# Trigram: ('son', 'december', 'death'), Bigram: ('december', 'death'), Unigram: ('death',)
# Trigram: ('december', 'death', 'alma'), Bigram: ('death', 'alma'), Unigram: ('alma',)
# Trigram: ('death', 'alma', 'feltner'), Bigram: ('alma', 'feltner'), Unigram: ('feltner',)
# Trigram: ('alma', 'feltner', 'mother'), Bigram: ('feltner', 'mother'), Unigram: ('mother',)
# Trigram: ('feltner', 'mother', 'june'), Bigram: ('mother', 'june'), Unigram: ('june',)
# Trigram: ('mother', 'june', 'appointed'), Bigram: ('june', 'appointed'), Unigram: ('appointed',)
# Trigram: ('june', 'appointed', 'attorney'), Bigram: ('appointed', 'attorney'), Unigram: ('attorney',)
# Trigram: ('appointed', 'attorney', 'brooklyn'), Bigram: ('attorney', 'brooklyn'), Unigram: ('brooklyn',)
# Trigram: ('attorney', 'brooklyn', 'dodger'), Bigram: ('brooklyn', 'dodger'), Unigram: ('dodger',)
# Trigram: ('brooklyn', 'dodger', 'president'), Bigram: ('dodger', 'president'), Unigram: ('president',)
# Trigram: ('dodger', 'president', 'chief'), Bigram: ('president', 'chief'), Unigram: ('chief',)
# Trigram: ('president', 'chief', 'stockholder'), Bigram: ('chief', 'stockholder'), Unigram: ('stockholder',)
# Trigram: ('chief', 'stockholder', 'dodger'), Bigram: ('stockholder', 'dodger'), Unigram: ('dodger',)
# Trigram: ('stockholder', 'dodger', 'october'), Bigram: ('dodger', 'october'), Unigram: ('october',)
# Trigram: ('dodger', 'october', 'death'), Bigram: ('october', 'death'), Unigram: ('death',)
# Trigram: ('october', 'death', 'edwin'), Bigram: ('death', 'edwin'), Unigram: ('edwin',)
# Trigram: ('death', 'edwin', 'joseph'), Bigram: ('edwin', 'joseph'), Unigram: ('joseph',)
# Trigram: ('edwin', 'joseph', 'omalley'), Bigram: ('joseph', 'omalley'), Unigram: ('omalley',)
# Trigram: ('joseph', 'omalley', 'father'), Bigram: ('omalley', 'father'), Unigram: ('father',)
# Trigram: ('omalley', 'father', 'april'), Bigram: ('father', 'april'), Unigram: ('april',)
# Trigram: ('father', 'april', 'dodger'), Bigram: ('april', 'dodger'), Unigram: ('dodger',)
# Trigram: ('april', 'dodger', 'win'), Bigram: ('dodger', 'win'), Unigram: ('win',)
# Trigram: ('dodger', 'win', 'world'), Bigram: ('win', 'world'), Unigram: ('world',)
# Trigram: ('win', 'world', 'series'), Bigram: ('world', 'series'), Unigram: ('series',)
# Trigram: ('world', 'series', 'team'), Bigram: ('series', 'team'), Unigram: ('team',)
# Trigram: ('series', 'team', 'moved'), Bigram: ('team', 'moved'), Unigram: ('moved',)
# Trigram: ('team', 'moved', 'los'), Bigram: ('moved', 'los'), Unigram: ('los',)
# Trigram: ('moved', 'los', 'angeles'), Bigram: ('los', 'angeles'), Unigram: ('angeles',)
# Trigram: ('los', 'angeles', 'dodger'), Bigram: ('angeles', 'dodger'), Unigram: ('dodger',)
# Trigram: ('angeles', 'dodger', 'win'), Bigram: ('dodger', 'win'), Unigram: ('win',)
# Trigram: ('dodger', 'win', 'world'), Bigram: ('win', 'world'), Unigram: ('world',)
# Trigram: ('win', 'world', 'series'), Bigram: ('world', 'series'), Unigram: ('series',)
# Trigram: ('world', 'series', 'dodger'), Bigram: ('series', 'dodger'), Unigram: ('dodger',)
# Trigram: ('series', 'dodger', 'win'), Bigram: ('dodger', 'win'), Unigram: ('win',)
# Trigram: ('dodger', 'win', 'world'), Bigram: ('win', 'world'), Unigram: ('world',)
# Trigram: ('win', 'world', 'series'), Bigram: ('world', 'series'), Unigram: ('series',)
# Trigram: ('world', 'series', 'dodger'), Bigram: ('series', 'dodger'), Unigram: ('dodger',)
# Trigram: ('series', 'dodger', 'win'), Bigram: ('dodger', 'win'), Unigram: ('win',)
# Trigram: ('dodger', 'win', 'world'), Bigram: ('win', 'world'), Unigram: ('world',)
# Trigram: ('win', 'world', 'series'), Bigram: ('world', 'series'), Unigram: ('series',)
# Trigram: ('world', 'series', 'peter'), Bigram: ('series', 'peter'), Unigram: ('peter',)
# Trigram: ('series', 'peter', 'omalley'), Bigram: ('peter', 'omalley'), Unigram: ('omalley',)
# Trigram: ('peter', 'omalley', 'son'), Bigram: ('omalley', 'son'), Unigram: ('son',)
# Trigram: ('omalley', 'son', 'becomes'), Bigram: ('son', 'becomes'), Unigram: ('becomes',)
# Trigram: ('son', 'becomes', 'president'), Bigram: ('becomes', 'president'), Unigram: ('president',)
# Trigram: ('becomes', 'president', 'dodger'), Bigram: ('president', 'dodger'), Unigram: ('dodger',)
# Trigram: ('president', 'dodger', 'march'), Bigram: ('dodger', 'march'), Unigram: ('march',)
# Trigram: ('dodger', 'march', 'dodger'), Bigram: ('march', 'dodger'), Unigram: ('dodger',)
# Trigram: ('march', 'dodger', 'win'), Bigram: ('dodger', 'win'), Unigram: ('win',)
# Trigram: ('dodger', 'win', 'national'), Bigram: ('win', 'national'), Unigram: ('national',)
# Trigram: ('win', 'national', 'league'), Bigram: ('national', 'league'), Unigram: ('league',)
# Trigram: ('national', 'league', 'championship'), Bigram: ('league', 'championship'), Unigram: ('championship',)
# Trigram: ('league', 'championship', 'series'), Bigram: ('championship', 'series'), Unigram: ('series',)
# Trigram: ('championship', 'series', 'walter'), Bigram: ('series', 'walter'), Unigram: ('walter',)
# Trigram: ('series', 'walter', 'st'), Bigram: ('walter', 'st'), Unigram: ('st',)
# Trigram: ('walter', 'st', 'birthday'), Bigram: ('st', 'birthday'), Unigram: ('birthday',)
# Trigram: ('st', 'birthday', 'omalley'), Bigram: ('birthday', 'omalley'), Unigram: ('omalley',)
# Trigram: ('birthday', 'omalley', 'owns'), Bigram: ('omalley', 'owns'), Unigram: ('owns',)
# Trigram: ('omalley', 'owns', 'dodger'), Bigram: ('owns', 'dodger'), Unigram: ('dodger',)
# Trigram: ('owns', 'dodger', 'stock'), Bigram: ('dodger', 'stock'), Unigram: ('stock',)
# Trigram: ('dodger', 'stock', 'chest'), Bigram: ('stock', 'chest'), Unigram: ('chest',)
# Trigram: ('stock', 'chest', 'surgery'), Bigram: ('chest', 'surgery'), Unigram: ('surgery',)
# Trigram: ('chest', 'surgery', 'los'), Bigram: ('surgery', 'los'), Unigram: ('los',)
# Trigram: ('surgery', 'los', 'angeles'), Bigram: ('los', 'angeles'), Unigram: ('angeles',)
# Trigram: ('los', 'angeles', 'june'), Bigram: ('angeles', 'june'), Unigram: ('june',)
# Trigram: ('angeles', 'june', 'death'), Bigram: ('june', 'death'), Unigram: ('death',)
# Trigram: ('june', 'death', 'kay'), Bigram: ('death', 'kay'), Unigram: ('kay',)
# Trigram: ('death', 'kay', 'wife'), Bigram: ('kay', 'wife'), Unigram: ('wife',)
# Trigram: ('kay', 'wife', 'los'), Bigram: ('wife', 'los'), Unigram: ('los',)
# Trigram: ('wife', 'los', 'angeles'), Bigram: ('los', 'angeles'), Unigram: ('angeles',)
# Trigram: ('los', 'angeles', 'july'), Bigram: ('angeles', 'july'), Unigram: ('july',)
# Trigram: ('angeles', 'july', 'treatment'), Bigram: ('july', 'treatment'), Unigram: ('treatment',)
# Trigram: ('july', 'treatment', 'mayo'), Bigram: ('treatment', 'mayo'), Unigram: ('mayo',)
# Trigram: ('treatment', 'mayo', 'clinic'), Bigram: ('mayo', 'clinic'), Unigram: ('clinic',)
# Trigram: ('mayo', 'clinic', 'minnesota'), Bigram: ('clinic', 'minnesota'), Unigram: ('minnesota',)
# Trigram: ('clinic', 'minnesota', 'death'), Bigram: ('minnesota', 'death'), Unigram: ('death',)
# Trigram: ('minnesota', 'death', 'walter'), Bigram: ('death', 'walter'), Unigram: ('walter',)
# Trigram: ('death', 'walter', 'omalley'), Bigram: ('walter', 'omalley'), Unigram: ('omalley',)
# Trigram: ('walter', 'omalley', 'mayo'), Bigram: ('omalley', 'mayo'), Unigram: ('mayo',)
# Trigram: ('omalley', 'mayo', 'clinic'), Bigram: ('mayo', 'clinic'), Unigram: ('clinic',)
# Trigram: ('mayo', 'clinic', 'minnesota'), Bigram: ('clinic', 'minnesota'), Unigram: ('minnesota',)
# Trigram: ('clinic', 'minnesota', 'august'), Bigram: ('minnesota', 'august'), Unigram: ('august',)
# Trigram: ('minnesota', 'august', 'elected'), Bigram: ('august', 'elected'), Unigram: ('elected',)
# Trigram: ('august', 'elected', 'baseball'), Bigram: ('elected', 'baseball'), Unigram: ('baseball',)
# Trigram: ('elected', 'baseball', 'hall'), Bigram: ('baseball', 'hall'), Unigram: ('hall',)
# Trigram: ('baseball', 'hall', 'fame'), Bigram: ('hall', 'fame'), Unigram: ('fame',)
# Trigram: ('hall', 'fame', 'december'), Bigram: ('fame', 'december'), Unigram: ('december',)
# Trigram: ('fame', 'december', 'inducted'), Bigram: ('december', 'inducted'), Unigram: ('inducted',)
# Trigram: ('december', 'inducted', 'baseball'), Bigram: ('inducted', 'baseball'), Unigram: ('baseball',)
# Trigram: ('inducted', 'baseball', 'hall'), Bigram: ('baseball', 'hall'), Unigram: ('hall',)
# Trigram: ('baseball', 'hall', 'fame'), Bigram: ('hall', 'fame'), Unigram: ('fame',)
# Trigram: ('hall', 'fame', 'july'), Bigram: ('fame', 'july'), Unigram: ('july',)
# Trigram: ('fame', 'july', 'induction'), Bigram: ('july', 'induction'), Unigram: ('induction',)
# Trigram: ('july', 'induction', 'irish'), Bigram: ('induction', 'irish'), Unigram: ('irish',)
# Trigram: ('induction', 'irish', 'american'), Bigram: ('irish', 'american'), Unigram: ('american',)
# Trigram: ('irish', 'american', 'baseball'), Bigram: ('american', 'baseball'), Unigram: ('baseball',)
# Trigram: ('american', 'baseball', 'hall'), Bigram: ('baseball', 'hall'), Unigram: ('hall',)
# Trigram: ('baseball', 'hall', 'fame'), Bigram: ('hall', 'fame'), Unigram: ('fame',)
# Trigram: ('hall', 'fame', 'new'), Bigram: ('fame', 'new'), Unigram: ('new',)
# Trigram: ('fame', 'new', 'york'), Bigram: ('new', 'york'), Unigram: ('york',)
# Trigram: ('new', 'york', 'city'), Bigram: ('york', 'city'), Unigram: ('city',)
# Trigram: ('york', 'city', 'july'), Bigram: ('city', 'july'), Unigram: ('july',)
# Trigram: ('city', 'july', 'reference'), Bigram: ('july', 'reference'), Unigram: ('reference',)
# Trigram: ('july', 'reference', 'reading'), Bigram: ('reference', 'reading'), Unigram: ('reading',)
# Trigram: ('reference', 'reading', 'accessed'), Bigram: ('reading', 'accessed'), Unigram: ('accessed',)
# Trigram: ('reading', 'accessed', 'online'), Bigram: ('accessed', 'online'), Unigram: ('online',)
# Trigram: ('accessed', 'online', 'google'), Bigram: ('online', 'google'), Unigram: ('google',)
# Trigram: ('online', 'google', 'book'), Bigram: ('google', 'book'), Unigram: ('book',)
# Trigram: ('google', 'book', 'stout'), Bigram: ('book', 'stout'), Unigram: ('stout',)
# Trigram: ('book', 'stout', 'glenn'), Bigram: ('stout', 'glenn'), Unigram: ('glenn',)
# Trigram: ('stout', 'glenn', 'richard'), Bigram: ('glenn', 'richard'), Unigram: ('richard',)
# Trigram: ('glenn', 'richard', 'johnson'), Bigram: ('richard', 'johnson'), Unigram: ('johnson',)
# Trigram: ('richard', 'johnson', 'photo'), Bigram: ('johnson', 'photo'), Unigram: ('photo',)
# Trigram: ('johnson', 'photo', 'editing'), Bigram: ('photo', 'editing'), Unigram: ('editing',)
# Trigram: ('photo', 'editing', 'dodger'), Bigram: ('editing', 'dodger'), Unigram: ('dodger',)
# Trigram: ('editing', 'dodger', 'year'), Bigram: ('dodger', 'year'), Unigram: ('year',)
# Trigram: ('dodger', 'year', 'dodger'), Bigram: ('year', 'dodger'), Unigram: ('dodger',)
# Trigram: ('year', 'dodger', 'baseball'), Bigram: ('dodger', 'baseball'), Unigram: ('baseball',)
# Trigram: ('dodger', 'baseball', 'houghton'), Bigram: ('baseball', 'houghton'), Unigram: ('houghton',)
# Trigram: ('baseball', 'houghton', 'mifflin'), Bigram: ('houghton', 'mifflin'), Unigram: ('mifflin',)
# Trigram: ('houghton', 'mifflin', 'company'), Bigram: ('mifflin', 'company'), Unigram: ('company',)
# Trigram: ('mifflin', 'company', 'bostonnew'), Bigram: ('company', 'bostonnew'), Unigram: ('bostonnew',)
# Trigram: ('company', 'bostonnew', 'york'), Bigram: ('bostonnew', 'york'), Unigram: ('york',)
# Trigram: ('bostonnew', 'york', 'external'), Bigram: ('york', 'external'), Unigram: ('external',)
# Trigram: ('york', 'external', 'link'), Bigram: ('external', 'link'), Unigram: ('link',)
# Trigram: ('external', 'link', 'omalley'), Bigram: ('link', 'omalley'), Unigram: ('omalley',)
# Trigram: ('link', 'omalley', 'archive'), Bigram: ('omalley', 'archive'), Unigram: ('archive',)
# Trigram: ('omalley', 'archive', 'los'), Bigram: ('archive', 'los'), Unigram: ('los',)
# Trigram: ('archive', 'los', 'angeles'), Bigram: ('los', 'angeles'), Unigram: ('angeles',)
# Trigram: ('los', 'angeles', 'time'), Bigram: ('angeles', 'time'), Unigram: ('time',)
# Trigram: ('angeles', 'time', 'birth'), Bigram: ('time', 'birth'), Unigram: ('birth',)
# Trigram: ('time', 'birth', 'death'), Bigram: ('birth', 'death'), Unigram: ('death',)
# Trigram: ('birth', 'death', 'american'), Bigram: ('death', 'american'), Unigram: ('american',)
# Trigram: ('death', 'american', 'sport'), Bigram: ('american', 'sport'), Unigram: ('sport',)
# Trigram: ('american', 'sport', 'businesspeople'), Bigram: ('sport', 'businesspeople'), Unigram: ('businesspeople',)
# Trigram: ('sport', 'businesspeople', 'brooklyn'), Bigram: ('businesspeople', 'brooklyn'), Unigram: ('brooklyn',)
# Trigram: ('businesspeople', 'brooklyn', 'dodger'), Bigram: ('brooklyn', 'dodger'), Unigram: ('dodger',)
# Trigram: ('brooklyn', 'dodger', 'executive'), Bigram: ('dodger', 'executive'), Unigram: ('executive',)
# Trigram: ('dodger', 'executive', 'brooklyn'), Bigram: ('executive', 'brooklyn'), Unigram: ('brooklyn',)
# Trigram: ('executive', 'brooklyn', 'dodger'), Bigram: ('brooklyn', 'dodger'), Unigram: ('dodger',)
# Trigram: ('brooklyn', 'dodger', 'owner'), Bigram: ('dodger', 'owner'), Unigram: ('owner',)
# Trigram: ('dodger', 'owner', 'burial'), Bigram: ('owner', 'burial'), Unigram: ('burial',)
# Trigram: ('owner', 'burial', 'holy'), Bigram: ('burial', 'holy'), Unigram: ('holy',)
# Trigram: ('burial', 'holy', 'cross'), Bigram: ('holy', 'cross'), Unigram: ('cross',)
# Trigram: ('holy', 'cross', 'cemetery'), Bigram: ('cross', 'cemetery'), Unigram: ('cemetery',)
# Trigram: ('cross', 'cemetery', 'culver'), Bigram: ('cemetery', 'culver'), Unigram: ('culver',)
# Trigram: ('cemetery', 'culver', 'city'), Bigram: ('culver', 'city'), Unigram: ('city',)
# Trigram: ('culver', 'city', 'columbia'), Bigram: ('city', 'columbia'), Unigram: ('columbia',)
# Trigram: ('city', 'columbia', 'law'), Bigram: ('columbia', 'law'), Unigram: ('law',)
# Trigram: ('columbia', 'law', 'school'), Bigram: ('law', 'school'), Unigram: ('school',)
# Trigram: ('law', 'school', 'alumnus'), Bigram: ('school', 'alumnus'), Unigram: ('alumnus',)
# Trigram: ('school', 'alumnus', 'fordham'), Bigram: ('alumnus', 'fordham'), Unigram: ('fordham',)
# Trigram: ('alumnus', 'fordham', 'university'), Bigram: ('fordham', 'university'), Unigram: ('university',)
# Trigram: ('fordham', 'university', 'school'), Bigram: ('university', 'school'), Unigram: ('school',)
# Trigram: ('university', 'school', 'law'), Bigram: ('school', 'law'), Unigram: ('law',)
# Trigram: ('school', 'law', 'alumnus'), Bigram: ('law', 'alumnus'), Unigram: ('alumnus',)
# Trigram: ('law', 'alumnus', 'los'), Bigram: ('alumnus', 'los'), Unigram: ('los',)
# Trigram: ('alumnus', 'los', 'angeles'), Bigram: ('los', 'angeles'), Unigram: ('angeles',)
# Trigram: ('los', 'angeles', 'dodger'), Bigram: ('angeles', 'dodger'), Unigram: ('dodger',)
# Trigram: ('angeles', 'dodger', 'executive'), Bigram: ('dodger', 'executive'), Unigram: ('executive',)
# Trigram: ('dodger', 'executive', 'los'), Bigram: ('executive', 'los'), Unigram: ('los',)
# Trigram: ('executive', 'los', 'angeles'), Bigram: ('los', 'angeles'), Unigram: ('angeles',)
# Trigram: ('los', 'angeles', 'dodger'), Bigram: ('angeles', 'dodger'), Unigram: ('dodger',)
# Trigram: ('angeles', 'dodger', 'owner'), Bigram: ('dodger', 'owner'), Unigram: ('owner',)
# Trigram: ('dodger', 'owner', 'major'), Bigram: ('owner', 'major'), Unigram: ('major',)
# Trigram: ('owner', 'major', 'league'), Bigram: ('major', 'league'), Unigram: ('league',)
# Trigram: ('major', 'league', 'baseball'), Bigram: ('league', 'baseball'), Unigram: ('baseball',)
# Trigram: ('league', 'baseball', 'executive'), Bigram: ('baseball', 'executive'), Unigram: ('executive',)
# Trigram: ('baseball', 'executive', 'major'), Bigram: ('executive', 'major'), Unigram: ('major',)
# Trigram: ('executive', 'major', 'league'), Bigram: ('major', 'league'), Unigram: ('league',)
# Trigram: ('major', 'league', 'baseball'), Bigram: ('league', 'baseball'), Unigram: ('baseball',)
# Trigram: ('league', 'baseball', 'owner'), Bigram: ('baseball', 'owner'), Unigram: ('owner',)
# Trigram: ('baseball', 'owner', 'major'), Bigram: ('owner', 'major'), Unigram: ('major',)
# Trigram: ('owner', 'major', 'league'), Bigram: ('major', 'league'), Unigram: ('league',)
# Trigram: ('major', 'league', 'baseball'), Bigram: ('league', 'baseball'), Unigram: ('baseball',)
# Trigram: ('league', 'baseball', 'team'), Bigram: ('baseball', 'team'), Unigram: ('team',)
# Trigram: ('baseball', 'team', 'president'), Bigram: ('team', 'president'), Unigram: ('president',)
# Trigram: ('team', 'president', 'national'), Bigram: ('president', 'national'), Unigram: ('national',)
# Trigram: ('president', 'national', 'baseball'), Bigram: ('national', 'baseball'), Unigram: ('baseball',)
# Trigram: ('national', 'baseball', 'hall'), Bigram: ('baseball', 'hall'), Unigram: ('hall',)
# Trigram: ('baseball', 'hall', 'fame'), Bigram: ('hall', 'fame'), Unigram: ('fame',)
# Trigram: ('hall', 'fame', 'inductee'), Bigram: ('fame', 'inductee'), Unigram: ('inductee',)
# Trigram: ('fame', 'inductee', 'walter'), Bigram: ('inductee', 'walter'), Unigram: ('walter',)
# Trigram: ('inductee', 'walter', 'people'), Bigram: ('walter', 'people'), Unigram: ('people',)
# Trigram: ('walter', 'people', 'bronx'), Bigram: ('people', 'bronx'), Unigram: ('bronx',)
# Trigram: ('people', 'bronx', 'people'), Bigram: ('bronx', 'people'), Unigram: ('people',)
# Trigram: ('bronx', 'people', 'amityville'), Bigram: ('people', 'amityville'), Unigram: ('amityville',)
# Trigram: ('people', 'amityville', 'new'), Bigram: ('amityville', 'new'), Unigram: ('new',)
# Trigram: ('amityville', 'new', 'york'), Bigram: ('new', 'york'), Unigram: ('york',)
# Trigram: ('new', 'york', 'university'), Bigram: ('york', 'university'), Unigram: ('university',)
# Trigram: ('york', 'university', 'pennsylvania'), Bigram: ('university', 'pennsylvania'), Unigram: ('pennsylvania',)
# Trigram: ('university', 'pennsylvania', 'school'), Bigram: ('pennsylvania', 'school'), Unigram: ('school',)
# Trigram: ('pennsylvania', 'school', 'engineering'), Bigram: ('school', 'engineering'), Unigram: ('engineering',)
# Trigram: ('school', 'engineering', 'applied'), Bigram: ('engineering', 'applied'), Unigram: ('applied',)
# Trigram: ('engineering', 'applied', 'science'), Bigram: ('applied', 'science'), Unigram: ('science',)
# Trigram: ('applied', 'science', 'alumnus'), Bigram: ('science', 'alumnus'), Unigram: ('alumnus',)
# Trigram: ('science', 'alumnus', 'catholic'), Bigram: ('alumnus', 'catholic'), Unigram: ('catholic',)
# Trigram: ('alumnus', 'catholic', 'new'), Bigram: ('catholic', 'new'), Unigram: ('new',)
# Trigram: ('catholic', 'new', 'york'), Bigram: ('new', 'york'), Unigram: ('york',)
# Trigram: ('new', 'york', 'state'), Bigram: ('york', 'state'), Unigram: ('state',)
# Trigram: ('york', 'state', 'culver'), Bigram: ('state', 'culver'), Unigram: ('culver',)
# Trigram: ('state', 'culver', 'academy'), Bigram: ('culver', 'academy'), Unigram: ('academy',)
# Trigram: ('culver', 'academy', 'alumnus'), Bigram: ('academy', 'alumnus'), Unigram: ('alumnus',)
# Trigram: ('academy', 'alumnus', 'thcentury'), Bigram: ('alumnus', 'thcentury'), Unigram: ('thcentury',)
# Trigram: ('alumnus', 'thcentury', 'american'), Bigram: ('thcentury', 'american'), Unigram: ('american',)
# Trigram: ('thcentury', 'american', 'people'), Bigram: ('american', 'people'), Unigram: ('people',)
# Trigram: ('american', 'people', 'gary'), Bigram: ('people', 'gary'), Unigram: ('gary',)
# Trigram: ('people', 'gary', 'winston'), Bigram: ('gary', 'winston'), Unigram: ('winston',)
# Trigram: ('gary', 'winston', 'lineker'), Bigram: ('winston', 'lineker'), Unigram: ('lineker',)
# Trigram: ('winston', 'lineker', 'born'), Bigram: ('lineker', 'born'), Unigram: ('born',)
# Trigram: ('lineker', 'born', 'november'), Bigram: ('born', 'november'), Unigram: ('november',)
# Trigram: ('born', 'november', 'english'), Bigram: ('november', 'english'), Unigram: ('english',)
# Trigram: ('november', 'english', 'former'), Bigram: ('english', 'former'), Unigram: ('former',)
# Trigram: ('english', 'former', 'professional'), Bigram: ('former', 'professional'), Unigram: ('professional',)
# Trigram: ('former', 'professional', 'footballer'), Bigram: ('professional', 'footballer'), Unigram: ('footballer',)
# Trigram: ('professional', 'footballer', 'current'), Bigram: ('footballer', 'current'), Unigram: ('current',)
# Trigram: ('footballer', 'current', 'sport'), Bigram: ('current', 'sport'), Unigram: ('sport',)
# Trigram: ('current', 'sport', 'broadcaster'), Bigram: ('sport', 'broadcaster'), Unigram: ('broadcaster',)
# Trigram: ('sport', 'broadcaster', 'regarded'), Bigram: ('broadcaster', 'regarded'), Unigram: ('regarded',)
# Trigram: ('broadcaster', 'regarded', 'one'), Bigram: ('regarded', 'one'), Unigram: ('one',)
# Trigram: ('regarded', 'one', 'greatest'), Bigram: ('one', 'greatest'), Unigram: ('greatest',)
# Trigram: ('one', 'greatest', 'english'), Bigram: ('greatest', 'english'), Unigram: ('english',)
# Trigram: ('greatest', 'english', 'striker'), Bigram: ('english', 'striker'), Unigram: ('striker',)
# Trigram: ('english', 'striker', 'medium'), Bigram: ('striker', 'medium'), Unigram: ('medium',)
# Trigram: ('striker', 'medium', 'career'), Bigram: ('medium', 'career'), Unigram: ('career',)
# Trigram: ('medium', 'career', 'began'), Bigram: ('career', 'began'), Unigram: ('began',)
# Trigram: ('career', 'began', 'bbc'), Bigram: ('began', 'bbc'), Unigram: ('bbc',)
# Trigram: ('began', 'bbc', 'presented'), Bigram: ('bbc', 'presented'), Unigram: ('presented',)
# Trigram: ('bbc', 'presented', 'flagship'), Bigram: ('presented', 'flagship'), Unigram: ('flagship',)
# Trigram: ('presented', 'flagship', 'football'), Bigram: ('flagship', 'football'), Unigram: ('football',)
# Trigram: ('flagship', 'football', 'programme'), Bigram: ('football', 'programme'), Unigram: ('programme',)
# Trigram: ('football', 'programme', 'match'), Bigram: ('programme', 'match'), Unigram: ('match',)
# Trigram: ('programme', 'match', 'day'), Bigram: ('match', 'day'), Unigram: ('day',)
# Trigram: ('match', 'day', 'since'), Bigram: ('day', 'since'), Unigram: ('since',)
# Trigram: ('day', 'since', 'late'), Bigram: ('since', 'late'), Unigram: ('late',)
# Trigram: ('since', 'late', 's'), Bigram: ('late', 's'), Unigram: ('s',)
# Trigram: ('late', 's', 'longest'), Bigram: ('s', 'longest'), Unigram: ('longest',)
# Trigram: ('s', 'longest', 'tenure'), Bigram: ('longest', 'tenure'), Unigram: ('tenure',)
# Trigram: ('longest', 'tenure', 'motd'), Bigram: ('tenure', 'motd'), Unigram: ('motd',)
# Trigram: ('tenure', 'motd', 'presenter'), Bigram: ('motd', 'presenter'), Unigram: ('presenter',)
# Trigram: ('motd', 'presenter', 'lineker'), Bigram: ('presenter', 'lineker'), Unigram: ('lineker',)
# Trigram: ('presenter', 'lineker', 'also'), Bigram: ('lineker', 'also'), Unigram: ('also',)
# Trigram: ('lineker', 'also', 'bbcs'), Bigram: ('also', 'bbcs'), Unigram: ('bbcs',)
# Trigram: ('also', 'bbcs', 'lead'), Bigram: ('bbcs', 'lead'), Unigram: ('lead',)
# Trigram: ('bbcs', 'lead', 'presenter'), Bigram: ('lead', 'presenter'), Unigram: ('presenter',)
# Trigram: ('lead', 'presenter', 'live'), Bigram: ('presenter', 'live'), Unigram: ('live',)
# Trigram: ('presenter', 'live', 'football'), Bigram: ('live', 'football'), Unigram: ('football',)
# Trigram: ('live', 'football', 'match'), Bigram: ('football', 'match'), Unigram: ('match',)
# Trigram: ('football', 'match', 'including'), Bigram: ('match', 'including'), Unigram: ('including',)
# Trigram: ('match', 'including', 'coverage'), Bigram: ('including', 'coverage'), Unigram: ('coverage',)
# Trigram: ('including', 'coverage', 'international'), Bigram: ('coverage', 'international'), Unigram: ('international',)
# Trigram: ('coverage', 'international', 'tournament'), Bigram: ('international', 'tournament'), Unigram: ('tournament',)
# Trigram: ('international', 'tournament', 'also'), Bigram: ('tournament', 'also'), Unigram: ('also',)
# Trigram: ('tournament', 'also', 'previously'), Bigram: ('also', 'previously'), Unigram: ('previously',)
# Trigram: ('also', 'previously', 'worked'), Bigram: ('previously', 'worked'), Unigram: ('worked',)
# Trigram: ('previously', 'worked', 'al'), Bigram: ('worked', 'al'), Unigram: ('al',)
# Trigram: ('worked', 'al', 'jazeera'), Bigram: ('al', 'jazeera'), Unigram: ('jazeera',)
# Trigram: ('al', 'jazeera', 'sport'), Bigram: ('jazeera', 'sport'), Unigram: ('sport',)
# Trigram: ('jazeera', 'sport', 'eredivisie'), Bigram: ('sport', 'eredivisie'), Unigram: ('eredivisie',)
# Trigram: ('sport', 'eredivisie', 'live'), Bigram: ('eredivisie', 'live'), Unigram: ('live',)
# Trigram: ('eredivisie', 'live', 'nbc'), Bigram: ('live', 'nbc'), Unigram: ('nbc',)
# Trigram: ('live', 'nbc', 'sport'), Bigram: ('nbc', 'sport'), Unigram: ('sport',)
# Trigram: ('nbc', 'sport', 'network'), Bigram: ('sport', 'network'), Unigram: ('network',)
# Trigram: ('sport', 'network', 'bt'), Bigram: ('network', 'bt'), Unigram: ('bt',)
# Trigram: ('network', 'bt', 'sport'), Bigram: ('bt', 'sport'), Unigram: ('sport',)
# Trigram: ('bt', 'sport', 'coverage'), Bigram: ('sport', 'coverage'), Unigram: ('coverage',)
# Trigram: ('sport', 'coverage', 'uefa'), Bigram: ('coverage', 'uefa'), Unigram: ('uefa',)
# Trigram: ('coverage', 'uefa', 'champion'), Bigram: ('uefa', 'champion'), Unigram: ('champion',)
# Trigram: ('uefa', 'champion', 'league'), Bigram: ('champion', 'league'), Unigram: ('league',)
# Trigram: ('champion', 'league', 'lineker'), Bigram: ('league', 'lineker'), Unigram: ('lineker',)
# Trigram: ('league', 'lineker', 'began'), Bigram: ('lineker', 'began'), Unigram: ('began',)
# Trigram: ('lineker', 'began', 'football'), Bigram: ('began', 'football'), Unigram: ('football',)
# Trigram: ('began', 'football', 'career'), Bigram: ('football', 'career'), Unigram: ('career',)
# Trigram: ('football', 'career', 'leicester'), Bigram: ('career', 'leicester'), Unigram: ('leicester',)
# Trigram: ('career', 'leicester', 'city'), Bigram: ('leicester', 'city'), Unigram: ('city',)
# Trigram: ('leicester', 'city', 'finished'), Bigram: ('city', 'finished'), Unigram: ('finished',)
# Trigram: ('city', 'finished', 'first'), Bigram: ('finished', 'first'), Unigram: ('first',)
# Trigram: ('finished', 'first', 'division'), Bigram: ('first', 'division'), Unigram: ('division',)
# Trigram: ('first', 'division', 'joint'), Bigram: ('division', 'joint'), Unigram: ('joint',)
# Trigram: ('division', 'joint', 'top'), Bigram: ('joint', 'top'), Unigram: ('top',)
# Trigram: ('joint', 'top', 'goalscorer'), Bigram: ('top', 'goalscorer'), Unigram: ('goalscorer',)
# Trigram: ('top', 'goalscorer', 'moved'), Bigram: ('goalscorer', 'moved'), Unigram: ('moved',)
# Trigram: ('goalscorer', 'moved', 'league'), Bigram: ('moved', 'league'), Unigram: ('league',)
# Trigram: ('moved', 'league', 'champion'), Bigram: ('league', 'champion'), Unigram: ('champion',)
# Trigram: ('league', 'champion', 'everton'), Bigram: ('champion', 'everton'), Unigram: ('everton',)
# Trigram: ('champion', 'everton', 'pfa'), Bigram: ('everton', 'pfa'), Unigram: ('pfa',)
# ...
# Trigram: ('go', 'start', 'wigan'), Bigram: ('start', 'wigan'), Unigram: ('wigan',)
# Trigram: ('start', 'wigan', 'final'), Bigram: ('wigan', 'final'), Unigram: ('final',)
# Trigram: ('wigan', 'final', 'manchester'), Bigram: ('final', 'manchester'), Unigram: ('manchester',)
# Trigram: ('final', 'manchester', 'united'), Bigram: ('manchester', 'united'), Unigram: ('united',)
# Trigram: ('manchester', 'united', 'blackburn'), Bigram: ('united', 'blackburn'), Unigram: ('blackburn',)
# Trigram: ('united', 'blackburn', 'rover'), Bigram: ('blackburn', 'rover'), Unigram: ('rover',)
# Trigram: ('blackburn', 'rover', 'july'), Bigram: ('rover', 'july'), Unigram: ('july',)
# Trigram: ('rover', 'july', 'joined'), Bigram: ('july', 'joined'), Unigram: ('joined',)
# Trigram: ('july', 'joined', 'blackburn'), Bigram: ('joined', 'blackburn'), Unigram: ('blackburn',)
# Trigram: ('joined', 'blackburn', 'rover'), Bigram: ('blackburn', 'rover'), Unigram: ('rover',)
# Trigram: ('blackburn', 'rover', 'fouryear'), Bigram: ('rover', 'fouryear'), Unigram: ('fouryear',)
# Trigram: ('rover', 'fouryear', 'contract'), Bigram: ('fouryear', 'contract'), Unigram: ('contract',)
# Trigram: ('fouryear', 'contract', 'undisclosed'), Bigram: ('contract', 'undisclosed'), Unigram: ('undisclosed',)
# Trigram: ('contract', 'undisclosed', 'fee'), Bigram: ('undisclosed', 'fee'), Unigram: ('fee',)
# Trigram: ('undisclosed', 'fee', 'scored'), Bigram: ('fee', 'scored'), Unigram: ('scored',)
# Trigram: ('fee', 'scored', 'first'), Bigram: ('scored', 'first'), Unigram: ('first',)
# Trigram: ('scored', 'first', 'goal'), Bigram: ('first', 'goal'), Unigram: ('goal',)
# Trigram: ('first', 'goal', 'blackburn'), Bigram: ('goal', 'blackburn'), Unigram: ('blackburn',)
# Trigram: ('goal', 'blackburn', 'fa'), Bigram: ('blackburn', 'fa'), Unigram: ('fa',)
# Trigram: ('blackburn', 'fa', 'cup'), Bigram: ('fa', 'cup'), Unigram: ('cup',)
# Trigram: ('fa', 'cup', 'semifinal'), Bigram: ('cup', 'semifinal'), Unigram: ('semifinal',)
# Trigram: ('cup', 'semifinal', 'defeat'), Bigram: ('semifinal', 'defeat'), Unigram: ('defeat',)
# Trigram: ('semifinal', 'defeat', 'chelsea'), Bigram: ('defeat', 'chelsea'), Unigram: ('chelsea',)
# Trigram: ('defeat', 'chelsea', 'missed'), Bigram: ('chelsea', 'missed'), Unigram: ('missed',)
# Trigram: ('chelsea', 'missed', 'three'), Bigram: ('missed', 'three'), Unigram: ('three',)
# Trigram: ('missed', 'three', 'month'), Bigram: ('three', 'month'), Unigram: ('month',)
# Trigram: ('three', 'month', 'season'), Bigram: ('month', 'season'), Unigram: ('season',)
# Trigram: ('month', 'season', 'broken'), Bigram: ('season', 'broken'), Unigram: ('broken',)
# Trigram: ('season', 'broken', 'foot'), Bigram: ('broken', 'foot'), Unigram: ('foot',)
# Trigram: ('broken', 'foot', 'robert'), Bigram: ('foot', 'robert'), Unigram: ('robert',)
# Trigram: ('foot', 'robert', 'kept'), Bigram: ('robert', 'kept'), Unigram: ('kept',)
# Trigram: ('robert', 'kept', 'momentum'), Bigram: ('kept', 'momentum'), Unigram: ('momentum',)
# Trigram: ('kept', 'momentum', 'towards'), Bigram: ('momentum', 'towards'), Unigram: ('towards',)
# Trigram: ('momentum', 'towards', 'end'), Bigram: ('towards', 'end'), Unigram: ('end',)
# Trigram: ('towards', 'end', 'season'), Bigram: ('end', 'season'), Unigram: ('season',)
# Trigram: ('end', 'season', 'netting'), Bigram: ('season', 'netting'), Unigram: ('netting',)
# Trigram: ('season', 'netting', 'five'), Bigram: ('netting', 'five'), Unigram: ('five',)
# Trigram: ('netting', 'five', 'goal'), Bigram: ('five', 'goal'), Unigram: ('goal',)
# Trigram: ('five', 'goal', 'many'), Bigram: ('goal', 'many'), Unigram: ('many',)
# Trigram: ('goal', 'many', 'game'), Bigram: ('many', 'game'), Unigram: ('game',)
# Trigram: ('many', 'game', 'shaking'), Bigram: ('game', 'shaking'), Unigram: ('shaking',)
# Trigram: ('game', 'shaking', 'criticism'), Bigram: ('shaking', 'criticism'), Unigram: ('criticism',)
# Trigram: ('shaking', 'criticism', 'many'), Bigram: ('criticism', 'many'), Unigram: ('many',)
# Trigram: ('criticism', 'many', 'fan'), Bigram: ('many', 'fan'), Unigram: ('fan',)
# Trigram: ('many', 'fan', 'following'), Bigram: ('fan', 'following'), Unigram: ('following',)
# Trigram: ('fan', 'following', 'season'), Bigram: ('following', 'season'), Unigram: ('season',)
# Trigram: ('following', 'season', 'struggled'), Bigram: ('season', 'struggled'), Unigram: ('struggled',)
# Trigram: ('season', 'struggled', 'maintain'), Bigram: ('struggled', 'maintain'), Unigram: ('maintain',)
# Trigram: ('struggled', 'maintain', 'place'), Bigram: ('maintain', 'place'), Unigram: ('place',)
# Trigram: ('maintain', 'place', 'blackburn'), Bigram: ('place', 'blackburn'), Unigram: ('blackburn',)
# Trigram: ('place', 'blackburn', 'starting'), Bigram: ('blackburn', 'starting'), Unigram: ('starting',)
# Trigram: ('blackburn', 'starting', 'line'), Bigram: ('starting', 'line'), Unigram: ('line',)
# Trigram: ('starting', 'line', 'due'), Bigram: ('line', 'due'), Unigram: ('due',)
# Trigram: ('line', 'due', 'signing'), Bigram: ('due', 'signing'), Unigram: ('signing',)
# Trigram: ('due', 'signing', 'bayern'), Bigram: ('signing', 'bayern'), Unigram: ('bayern',)
# Trigram: ('signing', 'bayern', 'munich'), Bigram: ('bayern', 'munich'), Unigram: ('munich',)
# Trigram: ('bayern', 'munich', 'striker'), Bigram: ('munich', 'striker'), Unigram: ('striker',)
# Trigram: ('munich', 'striker', 'roque'), Bigram: ('striker', 'roque'), Unigram: ('roque',)
# Trigram: ('striker', 'roque', 'santa'), Bigram: ('roque', 'santa'), Unigram: ('santa',)
# Trigram: ('roque', 'santa', 'cruz'), Bigram: ('santa', 'cruz'), Unigram: ('cruz',)
# Trigram: ('santa', 'cruz', 'however'), Bigram: ('cruz', 'however'), Unigram: ('however',)
# Trigram: ('cruz', 'however', 'memorable'), Bigram: ('however', 'memorable'), Unigram: ('memorable',)
# Trigram: ('however', 'memorable', 'solo'), Bigram: ('memorable', 'solo'), Unigram: ('solo',)
# Trigram: ('memorable', 'solo', 'goal'), Bigram: ('solo', 'goal'), Unigram: ('goal',)
# Trigram: ('solo', 'goal', 'rival'), Bigram: ('goal', 'rival'), Unigram: ('rival',)
# Trigram: ('goal', 'rival', 'bolton'), Bigram: ('rival', 'bolton'), Unigram: ('bolton',)
# Trigram: ('rival', 'bolton', 'wanderer'), Bigram: ('bolton', 'wanderer'), Unigram: ('wanderer',)
# Trigram: ('bolton', 'wanderer', 'claimed'), Bigram: ('wanderer', 'claimed'), Unigram: ('claimed',)
# Trigram: ('wanderer', 'claimed', 'back'), Bigram: ('claimed', 'back'), Unigram: ('back',)
# Trigram: ('claimed', 'back', 'place'), Bigram: ('back', 'place'), Unigram: ('place',)
# Trigram: ('back', 'place', 'took'), Bigram: ('place', 'took'), Unigram: ('took',)
# Trigram: ('place', 'took', 'part'), Bigram: ('took', 'part'), Unigram: ('part',)
# Trigram: ('took', 'part', 'many'), Bigram: ('part', 'many'), Unigram: ('many',)
# Trigram: ('part', 'many', 'game'), Bigram: ('many', 'game'), Unigram: ('game',)
# Trigram: ('many', 'game', 'towards'), Bigram: ('game', 'towards'), Unigram: ('towards',)
# Trigram: ('game', 'towards', 'end'), Bigram: ('towards', 'end'), Unigram: ('end',)
# Trigram: ('towards', 'end', 'season'), Bigram: ('end', 'season'), Unigram: ('season',)
# Trigram: ('end', 'season', 'netting'), Bigram: ('season', 'netting'), Unigram: ('netting',)
# Trigram: ('season', 'netting', 'goal'), Bigram: ('netting', 'goal'), Unigram: ('goal',)
# Trigram: ('netting', 'goal', 'forging'), Bigram: ('goal', 'forging'), Unigram: ('forging',)
# Trigram: ('goal', 'forging', 'good'), Bigram: ('forging', 'good'), Unigram: ('good',)
# Trigram: ('forging', 'good', 'partnership'), Bigram: ('good', 'partnership'), Unigram: ('partnership',)
# Trigram: ('good', 'partnership', 'santa'), Bigram: ('partnership', 'santa'), Unigram: ('santa',)
# Trigram: ('partnership', 'santa', 'cruz'), Bigram: ('santa', 'cruz'), Unigram: ('cruz',)
# Trigram: ('santa', 'cruz', 'robert'), Bigram: ('cruz', 'robert'), Unigram: ('robert',)
# Trigram: ('cruz', 'robert', 'scored'), Bigram: ('robert', 'scored'), Unigram: ('scored',)
# Trigram: ('robert', 'scored', 'seven'), Bigram: ('scored', 'seven'), Unigram: ('seven',)
# Trigram: ('scored', 'seven', 'league'), Bigram: ('seven', 'league'), Unigram: ('league',)
# Trigram: ('seven', 'league', 'goal'), Bigram: ('league', 'goal'), Unigram: ('goal',)
# Trigram: ('league', 'goal', 'season'), Bigram: ('goal', 'season'), Unigram: ('season',)
# Trigram: ('goal', 'season', 'blackburn'), Bigram: ('season', 'blackburn'), Unigram: ('blackburn',)
# Trigram: ('season', 'blackburn', 'struggled'), Bigram: ('blackburn', 'struggled'), Unigram: ('struggled',)
# Trigram: ('blackburn', 'struggled', 'league'), Bigram: ('struggled', 'league'), Unigram: ('league',)
# Trigram: ('struggled', 'league', 'finishing'), Bigram: ('league', 'finishing'), Unigram: ('finishing',)
# Trigram: ('league', 'finishing', 'th'), Bigram: ('finishing', 'th'), Unigram: ('th',)
# Trigram: ('finishing', 'th', 'signed'), Bigram: ('th', 'signed'), Unigram: ('signed',)
# Trigram: ('th', 'signed', 'new'), Bigram: ('signed', 'new'), Unigram: ('new',)
# Trigram: ('signed', 'new', 'deal'), Bigram: ('new', 'deal'), Unigram: ('deal',)
# Trigram: ('new', 'deal', 'november'), Bigram: ('deal', 'november'), Unigram: ('november',)
# Trigram: ('deal', 'november', 'kept'), Bigram: ('november', 'kept'), Unigram: ('kept',)
# Trigram: ('november', 'kept', 'ewood'), Bigram: ('kept', 'ewood'), Unigram: ('ewood',)
# Trigram: ('kept', 'ewood', 'park'), Bigram: ('ewood', 'park'), Unigram: ('park',)
# Trigram: ('ewood', 'park', 'summer'), Bigram: ('park', 'summer'), Unigram: ('summer',)
# Trigram: ('park', 'summer', 'end'), Bigram: ('summer', 'end'), Unigram: ('end',)
# Trigram: ('summer', 'end', 'season'), Bigram: ('end', 'season'), Unigram: ('season',)
# Trigram: ('end', 'season', 'robert'), Bigram: ('season', 'robert'), Unigram: ('robert',)
# Trigram: ('season', 'robert', 'scored'), Bigram: ('robert', 'scored'), Unigram: ('scored',)
# Trigram: ('robert', 'scored', 'five'), Bigram: ('scored', 'five'), Unigram: ('five',)
# Trigram: ('scored', 'five', 'goal'), Bigram: ('five', 'goal'), Unigram: ('goal',)
# Trigram: ('five', 'goal', 'appearance'), Bigram: ('goal', 'appearance'), Unigram: ('appearance',)
# Trigram: ('goal', 'appearance', 'helping'), Bigram: ('appearance', 'helping'), Unigram: ('helping',)
# Trigram: ('appearance', 'helping', 'blackburn'), Bigram: ('helping', 'blackburn'), Unigram: ('blackburn',)
# Trigram: ('helping', 'blackburn', 'finish'), Bigram: ('blackburn', 'finish'), Unigram: ('finish',)
# Trigram: ('blackburn', 'finish', 'th'), Bigram: ('finish', 'th'), Unigram: ('th',)
# Trigram: ('finish', 'th', 'league'), Bigram: ('th', 'league'), Unigram: ('league',)
# Trigram: ('th', 'league', 'reading'), Bigram: ('league', 'reading'), Unigram: ('reading',)
# Trigram: ('league', 'reading', 'january'), Bigram: ('reading', 'january'), Unigram: ('january',)
# Trigram: ('reading', 'january', 'robert'), Bigram: ('january', 'robert'), Unigram: ('robert',)
# Trigram: ('january', 'robert', 'signed'), Bigram: ('robert', 'signed'), Unigram: ('signed',)
# Trigram: ('robert', 'signed', 'reading'), Bigram: ('signed', 'reading'), Unigram: ('reading',)
# Trigram: ('signed', 'reading', 'eighteenmonth'), Bigram: ('reading', 'eighteenmonth'), Unigram: ('eighteenmonth',)
# Trigram: ('reading', 'eighteenmonth', 'contract'), Bigram: ('eighteenmonth', 'contract'), Unigram: ('contract',)
# Trigram: ('eighteenmonth', 'contract', 'robert'), Bigram: ('contract', 'robert'), Unigram: ('robert',)
# Trigram: ('contract', 'robert', 'scored'), Bigram: ('robert', 'scored'), Unigram: ('scored',)
# Trigram: ('robert', 'scored', 'debut'), Bigram: ('scored', 'debut'), Unigram: ('debut',)
# Trigram: ('scored', 'debut', 'bristol'), Bigram: ('debut', 'bristol'), Unigram: ('bristol',)
# Trigram: ('debut', 'bristol', 'city'), Bigram: ('bristol', 'city'), Unigram: ('city',)
# Trigram: ('bristol', 'city', 'january'), Bigram: ('city', 'january'), Unigram: ('january',)
# Trigram: ('city', 'january', 'david'), Bigram: ('january', 'david'), Unigram: ('david',)
# Trigram: ('january', 'david', 'james'), Bigram: ('david', 'james'), Unigram: ('james',)
# Trigram: ('david', 'james', 'saved'), Bigram: ('james', 'saved'), Unigram: ('saved',)
# Trigram: ('james', 'saved', 'penalty'), Bigram: ('saved', 'penalty'), Unigram: ('penalty',)
# Trigram: ('saved', 'penalty', 'robert'), Bigram: ('penalty', 'robert'), Unigram: ('robert',)
# Trigram: ('penalty', 'robert', 'bundled'), Bigram: ('robert', 'bundled'), Unigram: ('bundled',)
# Trigram: ('robert', 'bundled', 'ball'), Bigram: ('bundled', 'ball'), Unigram: ('ball',)
# Trigram: ('bundled', 'ball', 'line'), Bigram: ('ball', 'line'), Unigram: ('line',)
# Trigram: ('ball', 'line', 'rebound'), Bigram: ('line', 'rebound'), Unigram: ('rebound',)
# Trigram: ('line', 'rebound', 'second'), Bigram: ('rebound', 'second'), Unigram: ('second',)
# Trigram: ('rebound', 'second', 'goal'), Bigram: ('second', 'goal'), Unigram: ('goal',)
# Trigram: ('second', 'goal', 'came'), Bigram: ('goal', 'came'), Unigram: ('came',)
# Trigram: ('goal', 'came', 'february'), Bigram: ('came', 'february'), Unigram: ('february',)
# Trigram: ('came', 'february', 'coventry'), Bigram: ('february', 'coventry'), Unigram: ('coventry',)
# Trigram: ('february', 'coventry', 'city'), Bigram: ('coventry', 'city'), Unigram: ('city',)
# Trigram: ('coventry', 'city', 'deflected'), Bigram: ('city', 'deflected'), Unigram: ('deflected',)
# Trigram: ('city', 'deflected', 'matthew'), Bigram: ('deflected', 'matthew'), Unigram: ('matthew',)
# Trigram: ('deflected', 'matthew', 'connolly'), Bigram: ('matthew', 'connolly'), Unigram: ('connolly',)
# Trigram: ('matthew', 'connolly', 'header'), Bigram: ('connolly', 'header'), Unigram: ('header',)
# Trigram: ('connolly', 'header', 'scored'), Bigram: ('header', 'scored'), Unigram: ('scored',)
# Trigram: ('header', 'scored', 'third'), Bigram: ('scored', 'third'), Unigram: ('third',)
# Trigram: ('scored', 'third', 'goal'), Bigram: ('third', 'goal'), Unigram: ('goal',)
# Trigram: ('third', 'goal', 'four'), Bigram: ('goal', 'four'), Unigram: ('four',)
# Trigram: ('goal', 'four', 'start'), Bigram: ('four', 'start'), Unigram: ('start',)
# Trigram: ('four', 'start', 'win'), Bigram: ('start', 'win'), Unigram: ('win',)
# Trigram: ('start', 'win', 'burnley'), Bigram: ('win', 'burnley'), Unigram: ('burnley',)
# Trigram: ('win', 'burnley', 'looping'), Bigram: ('burnley', 'looping'), Unigram: ('looping',)
# Trigram: ('burnley', 'looping', 'jobi'), Bigram: ('looping', 'jobi'), Unigram: ('jobi',)
# Trigram: ('looping', 'jobi', 'mcanuff'), Bigram: ('jobi', 'mcanuff'), Unigram: ('mcanuff',)
# Trigram: ('jobi', 'mcanuff', 'cross'), Bigram: ('mcanuff', 'cross'), Unigram: ('cross',)
# Trigram: ('mcanuff', 'cross', 'keeper'), Bigram: ('cross', 'keeper'), Unigram: ('keeper',)
# Trigram: ('cross', 'keeper', 'lee'), Bigram: ('keeper', 'lee'), Unigram: ('lee',)
# Trigram: ('keeper', 'lee', 'grant'), Bigram: ('lee', 'grant'), Unigram: ('grant',)
# Trigram: ('lee', 'grant', 'march'), Bigram: ('grant', 'march'), Unigram: ('march',)
# Trigram: ('grant', 'march', 'robert'), Bigram: ('march', 'robert'), Unigram: ('robert',)
# Trigram: ('march', 'robert', 'got'), Bigram: ('robert', 'got'), Unigram: ('got',)
# Trigram: ('robert', 'got', 'scoresheet'), Bigram: ('got', 'scoresheet'), Unigram: ('scoresheet',)
# Trigram: ('got', 'scoresheet', 'goal'), Bigram: ('scoresheet', 'goal'), Unigram: ('goal',)
# Trigram: ('scoresheet', 'goal', 'close'), Bigram: ('goal', 'close'), Unigram: ('close',)
# Trigram: ('goal', 'close', 'bottom'), Bigram: ('close', 'bottom'), Unigram: ('bottom',)
# Trigram: ('close', 'bottom', 'left'), Bigram: ('bottom', 'left'), Unigram: ('left',)
# Trigram: ('bottom', 'left', 'corner'), Bigram: ('left', 'corner'), Unigram: ('corner',)
# Trigram: ('left', 'corner', 'goal'), Bigram: ('corner', 'goal'), Unigram: ('goal',)
# Trigram: ('corner', 'goal', 'leicester'), Bigram: ('goal', 'leicester'), Unigram: ('leicester',)
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
print("Trigram type:", type(trigram), "Value:", trigram)
print("Bigram type:", type(bigram), "Value:", bigram)
print("Unigram type:", type(unigram), "Value:", unigram)
# Out:
# Trigram type: <class 'tuple'> Value: ('cup', 'final', 'player')
# Bigram type: <class 'tuple'> Value: ('final', 'player')
# Unigram type: <class 'tuple'> Value: ('player',)

# %%
from scipy.optimize import minimize
import numpy as np

# Constraint: λ1 + λ2 + λ3 = 1
constraints = {'type': 'eq', 'fun': lambda lambdas: sum(lambdas) - 1}

# Bounds: Each λ should be between 0 and 1
bounds = [(0, 1), (0, 1), (0, 1)]

# Initial values (equal weights)
initial_lambdas = [1/3, 1/3, 1/3]

# Optimize λ values to minimize perplexity
result = minimize(perplexity_interpolation, initial_lambdas, 
                  args=(validation_tokens, unigram_probs, bigram_probs, trigram_probs),
                  bounds=bounds, constraints=constraints, method='SLSQP')

# Optimized λ values
optimized_lambdas = result.x
print("Optimized Lambda Values:", optimized_lambdas)
# Out:
# Optimized Lambda Values: [0. 0. 1.]

# %%
# Extract tokens from test set
test_tokens = test_df["tokens"].explode().tolist()

# Compute perplexity on test set using optimized lambda values
test_perplexity = perplexity_interpolation(optimized_lambdas, test_tokens, unigram_probs, bigram_probs, trigram_probs)

print("Test Set Perplexity:", test_perplexity)
# Out:
# Test Set Perplexity: 121.05203587603539
